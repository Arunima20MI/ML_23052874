# %%
def _Gradient(X,Y,n,B0,B1,A):
    print(f"Intersection B0 Initially : {B0}")
    print(f"Slope B1 Initially : {B1}")
    iter = int(input("Enter the no of Iteration : "))
    for _ in range(iter):
        Y_predicted  = []
        for i in range(n):   
            Y_predicted.append(B0 + B1 * X[i]) 
        loss = 0.0
        for i in range(n):
            loss += (Y_predicted[i] - Y[i]) ** 2
        loss /= (2 * n)  
        dB1 = 0.0 
        dB0 = 0.0 
        for i in range(n):
            error = Y_predicted[i] - Y[i]
            dB1 += error*X[i]
            dB0 +=error
        dB1 /= n
        dB0 /= n
        B1 = B1 - A*dB1
        B0 = B0 - A*dB0
        print(f"Intercept B0 : {B0}")
        print(f"Slope B1     : {B1}")
        print(f"Loss         : {loss}")
        print()
def _main():
    n = int(input("Enter the number of Terms : "))
    X,Y = [],[] 
    for i in range(n):
        X.append(float(input(f"Enter the Value of X{i+1} : ")))
        Y.append(float(input(f"Enter the Value of Y{i+1} : ")))
    B0 = float(input("Enter the Intersection B0 : "))
    B1 = float(input("Enter the Slope B1 : "))
    A = float(input("Enter the Learning Rate A(alpha) : ")) 
    _Gradient(X,Y,n,B0,B1,A)
_main()
# Out:
# Enter the number of Terms :  4
# Enter the Value of X1 :  2
# Enter the Value of Y1 :  -3
# Enter the Value of X2 :  0
# Enter the Value of Y2 :  0
# Enter the Value of X3 :  1
# Enter the Value of Y3 :  6
# Enter the Value of X4 :  -1
# Enter the Value of Y4 :  -4
# Enter the Intersection B0 :  5
# Enter the Slope B1 :  1
# Enter the Learning Rate A(alpha) :  0.4
# Intersection B0 Initially : 5.0
# Slope B1 Initially : 1.0
# Enter the no of Iteration :  3
# Intercept B0 : 2.6999999999999997
# Slope B1     : -0.20000000000000018
# Loss         : 23.625
#
# Intercept B0 : 1.5599999999999998
# Slope B1     : -0.21999999999999992
# Loss         : 11.905000000000001
#
# Intercept B0 : 0.8799999999999999
# Slope B1     : 2.7755575615628914e-17
# Loss         : 9.316499999999998
